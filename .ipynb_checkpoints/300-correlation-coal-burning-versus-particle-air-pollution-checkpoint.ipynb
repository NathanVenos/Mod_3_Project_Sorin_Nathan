# %%
import os.path
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline

# %%
cwd = os.getcwd()
data_path = os.path.join(cwd, "data-temp", "API_EN.ATM.PM25.MC.M3_DS2_en_csv_v2_248798.csv")
meta_path = os.path.join(cwd, "data-temp", "Metadata_Country_API_EN.ATM.PM25.MC.M3_DS2_en_csv_v2_248798.csv")

data_path, meta_path
# !ls data-temp/
# Out:
# ('/home/sorin/myData/PROJ-flatiron/project-mod3/data-temp/API_EN.ATM.PM25.MC.M3_DS2_en_csv_v2_248798.csv',
#  '/home/sorin/myData/PROJ-flatiron/project-mod3/data-temp/Metadata_Country_API_EN.ATM.PM25.MC.M3_DS2_en_csv_v2_248798.csv')

# %%
data_df = pd.read_csv(data_path, skiprows=4)
# data_df.info()

# %%
columns_to_drop = set(data_df.columns).difference({"Country Code", "Country Name",
                                                   "1990", "1995", "2000", "2005", "2010", "2011",
                                                   "2012", "2013", "2014", "2015", "2016", "2017"})
data_df.drop(columns=list(columns_to_drop), inplace=True)
data_df.dropna(thresh=5, inplace=True)
data_df
# Out:
#      Country Name Country Code       1990       1995       2000       2005  \
# 1     Afghanistan          AFG  65.486792  65.179513  64.922462  64.522683
# 2          Angola          AGO  36.448116  35.602908  36.182968  34.962912
# 3         Albania          ALB  22.718663  22.029218  21.998248  21.575258
# 4         Andorra          AND  14.118742  13.936867  12.594015  12.961378
# 5      Arab World          ARB  53.300266  52.543409  53.063076  52.395251
# ..            ...          ...        ...        ...        ...        ...
# 258         Samoa          WSM  14.311250  14.296988  14.320470  14.205458
# 260   Yemen, Rep.          YEM  48.863727  50.027716  50.867933  45.144808
# 261  South Africa          ZAF  26.120203  26.285373  26.673799  26.322878
# 262        Zambia          ZMB  32.764845  30.908466  30.898204  28.947055
# 263      Zimbabwe          ZWE  23.319908  22.726269  23.126373  23.314742
#
#           2010       2011       2012       2013       2014       2015  \
# 1    65.245592  66.835727  66.023174  61.366745  59.010330  61.252656
# 2    33.787247  33.104195  33.415495  34.663923  32.974025  32.729873
# 3    21.277828  22.772537  20.578259  19.938517  18.883955  19.512540
# 4    12.807197  13.273506  12.407053  11.813673  10.830418  11.462178
# 5    53.787001  52.652279  53.297270  54.053822  52.583603  60.406813
# ..         ...        ...        ...        ...        ...        ...
# 258  14.288094  14.693096  13.627882  13.382522  12.643560  12.321796
# 260  45.979470  50.835291  51.434454  52.998443  48.338653  54.260287
# 261  27.138587  26.557873  26.577087  26.729262  26.722212  26.112972
# 262  28.836379  28.987117  29.742040  29.112221  28.493252  28.375452
# 263  23.231479  23.074213  23.198097  23.111088  22.805950  21.733709
#
#           2016       2017
# 1    56.287047  56.910808
# 2    31.785389  32.388505
# 3    18.189934  18.200603
# 4    10.255834  10.307621
# 5    58.764905  58.689259
# ..         ...        ...
# 258  11.366298  11.548027
# 260  50.127626  50.456007
# 261  25.140416  25.102205
# 262  27.355674  27.438035
# 263  21.726947  22.251671
#
# [240 rows x 14 columns]

# %%
meta_df = pd.read_csv(meta_path)
meta_df
# Out:
#     Country Code                      Region          IncomeGroup  \
# 0            ABW   Latin America & Caribbean          High income
# 1            AFG                  South Asia           Low income
# 2            AGO          Sub-Saharan Africa  Lower middle income
# 3            ALB       Europe & Central Asia  Upper middle income
# 4            AND       Europe & Central Asia          High income
# ..           ...                         ...                  ...
# 258          XKX       Europe & Central Asia  Upper middle income
# 259          YEM  Middle East & North Africa           Low income
# 260          ZAF          Sub-Saharan Africa  Upper middle income
# 261          ZMB          Sub-Saharan Africa  Lower middle income
# 262          ZWE          Sub-Saharan Africa  Lower middle income
#
#                                           SpecialNotes     TableName  \
# 0                                                  NaN         Aruba
# 1                                                  NaN   Afghanistan
# 2                                                  NaN        Angola
# 3                                                  NaN       Albania
# 4                                                  NaN       Andorra
# ..                                                 ...           ...
# 258                                                NaN        Kosovo
# 259                                                NaN   Yemen, Rep.
# 260  Fiscal year end: March 31; reporting period fo...  South Africa
# 261  National accounts data were rebased to reflect...        Zambia
# 262                                                NaN      Zimbabwe
#
#      Unnamed: 5
# 0           NaN
# 1           NaN
# 2           NaN
# 3           NaN
# 4           NaN
# ..          ...
# 258         NaN
# 259         NaN
# 260         NaN
# 261         NaN
# 262         NaN
#
# [263 rows x 6 columns]

# %%
df = pd.merge(data_df, meta_df[["Country Code", "Region", "IncomeGroup"]], how="left")
df
# Out:
#      Country Name Country Code       1990       1995       2000       2005  \
# 0     Afghanistan          AFG  65.486792  65.179513  64.922462  64.522683
# 1          Angola          AGO  36.448116  35.602908  36.182968  34.962912
# 2         Albania          ALB  22.718663  22.029218  21.998248  21.575258
# 3         Andorra          AND  14.118742  13.936867  12.594015  12.961378
# 4      Arab World          ARB  53.300266  52.543409  53.063076  52.395251
# ..            ...          ...        ...        ...        ...        ...
# 235         Samoa          WSM  14.311250  14.296988  14.320470  14.205458
# 236   Yemen, Rep.          YEM  48.863727  50.027716  50.867933  45.144808
# 237  South Africa          ZAF  26.120203  26.285373  26.673799  26.322878
# 238        Zambia          ZMB  32.764845  30.908466  30.898204  28.947055
# 239      Zimbabwe          ZWE  23.319908  22.726269  23.126373  23.314742
#
#           2010       2011       2012       2013       2014       2015  \
# 0    65.245592  66.835727  66.023174  61.366745  59.010330  61.252656
# 1    33.787247  33.104195  33.415495  34.663923  32.974025  32.729873
# 2    21.277828  22.772537  20.578259  19.938517  18.883955  19.512540
# 3    12.807197  13.273506  12.407053  11.813673  10.830418  11.462178
# 4    53.787001  52.652279  53.297270  54.053822  52.583603  60.406813
# ..         ...        ...        ...        ...        ...        ...
# 235  14.288094  14.693096  13.627882  13.382522  12.643560  12.321796
# 236  45.979470  50.835291  51.434454  52.998443  48.338653  54.260287
# 237  27.138587  26.557873  26.577087  26.729262  26.722212  26.112972
# 238  28.836379  28.987117  29.742040  29.112221  28.493252  28.375452
# 239  23.231479  23.074213  23.198097  23.111088  22.805950  21.733709
#
#           2016       2017                      Region          IncomeGroup
# 0    56.287047  56.910808                  South Asia           Low income
# 1    31.785389  32.388505          Sub-Saharan Africa  Lower middle income
# 2    18.189934  18.200603       Europe & Central Asia  Upper middle income
# 3    10.255834  10.307621       Europe & Central Asia          High income
# 4    58.764905  58.689259                         NaN                  NaN
# ..         ...        ...                         ...                  ...
# 235  11.366298  11.548027         East Asia & Pacific  Upper middle income
# 236  50.127626  50.456007  Middle East & North Africa           Low income
# 237  25.140416  25.102205          Sub-Saharan Africa  Upper middle income
# 238  27.355674  27.438035          Sub-Saharan Africa  Lower middle income
# 239  21.726947  22.251671          Sub-Saharan Africa  Lower middle income
#
# [240 rows x 16 columns]

# %%
f, ax = plt.subplots(figsize=(12, 8))

ax = sns.swarmplot(data=df, y="Region", x="2017", hue="IncomeGroup", size=8, ax=ax, dodge=False, palette="cividis");

# (g.set_axis_labels("PM2.5 concentration", "Region")
#     .set_xticklabels(["Men", "Women", "Children"])
#     .set_titles("{col_name} {col_var}")
#     .set(ylim=(0, 1))
#     .despine(left=True)
# )
